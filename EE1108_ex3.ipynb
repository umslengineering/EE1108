# %% [markdown]
# <a href="https://colab.research.google.com/github/umslengineering/EE1108/blob/main/EE1108_ex3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kirby Video Games

# %%
# !pip install pygame pgzero
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.3/71.3 kB 2.8 MB/s eta 0:00:00
# ...

# %% [markdown]
# Kirby Games: To run use terminal pgzrun code.py

# %%
from random import randint

WIDTH = 400
HEIGHT = 400
score = 0
game_over = False
kirby = Actor("kirby")
kirby.pos = 100, 100
coin = Actor("coin")
coin.pos = 200, 200

def draw():
    screen.fill("green")
    kirby.draw()
    coin.draw()
    screen.draw.text("Score: " + str(score), color="black", topleft=(10, 10))

    if game_over:
        screen.fill("pink")
        screen.draw.text("Final Score: " + str(score), topleft=(10, 10), fontsize=60)

def place_coin():
    coin.x = randint(20, (WIDTH - 20))
    coin.y = randint(20, (HEIGHT - 20))


def time_up():
    global game_over
    game_over = True

def update():
    global score
    if keyboard.left:
        kirby.x = kirby.x - 2
    elif keyboard.right:
        kirby.x = kirby.x + 2
    elif keyboard.up:
        kirby.y = kirby.y - 2
    elif keyboard.down:
        kirby.y = kirby.y + 2

    coin_collected = kirby.colliderect(coin)

    if coin_collected:
        score = score + 10
        place_coin()

clock.schedule(time_up, 20.0)
place_coin()
